# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = '../../data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12

# %%
#1
male = data[(data['Year'] == 1992) & (data['Sex'] == 'M')]['Age'].min()
female = data[(data['Year'] == 1992) & (data['Sex'] == 'F')]['Age'].min()
print(male, female)
# Out:
# 11.0 12.0

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
#считаем баскетболистов
i1 = data[(data['Sport'] == 'Basketball') & (data['Sex'] == 'M') & (data['Year'] == 2012)]['ID'].count()

#считаем всего
i2 = data[(data['Sex'] == 'M') & (data['Year'] == 2012)]['ID'].unique().size

#отношение
print('Всего баскетболистов: {}, всего участников: {}, процент: {}'.format(i1, i2, i1/i2*100))
# Out:
# Всего баскетболистов: 144, всего участников: 5863, процент: 2.4560805048609926

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
print(data['Sex'].value_counts())
ft = data[(data['Sex'] == 'F') & (data['Year'] == 2000)  & (data['Sport'] == 'Tennis')]['Height']
print('Среднее: {}, Стандартное отклонение: {}'.format(round(ft.mean(),1), round(ft.std(),1)))
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64
# Среднее: 171.8, Стандартное отклонение: 6.5

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton
# - Boxing

# %%
# You code here
# max
weights = data[data['Year'] == 2006]['Weight']
weights.max()
#his sport
data[(data['Year'] == 2006) & (data['Weight'] == weights.max())]['Sport']
# Out:
# 8102    Skeleton
# Name: Sport, dtype: object

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
data[(data['Name'] == 'John Aalberg')]['Year'].unique()
# Out:
# array([1992, 1994], dtype=int64)

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2
# - 3

# %%
# просто золото
data[(data['Year'] == 2008) & (data['Sport'] == 'Tennis') & (data['Medal'] == 'Gold')]
# Out:
#             ID                                             Name Sex   Age  \
# 53519    27457  Yelena Vyacheslavovna Dementyeva (-Afinogenova)   F  26.0
# 67290    34396                                    Roger Federer   M  26.0
# 167223   84006                              Rafael Nadal Parera   M  22.0
# 257672  129042                               Stanislas Wawrinka   M  23.0
# 261109  130667                           Serena Jamika Williams   F  26.0
# 261163  130696                       Venus Ebony Starr Williams   F  28.0
#
#         Height  Weight             Team  NOC        Games  Year  Season  \
# 53519    180.0    64.0           Russia  RUS  2008 Summer  2008  Summer
# 67290    185.0    80.0      Switzerland  SUI  2008 Summer  2008  Summer
# 167223   185.0    80.0            Spain  ESP  2008 Summer  2008  Summer
# 257672   183.0    79.0      Switzerland  SUI  2008 Summer  2008  Summer
# 261109   175.0    70.0  United States-2  USA  2008 Summer  2008  Summer
# 261163   185.0    75.0  United States-2  USA  2008 Summer  2008  Summer
#
#            City   Sport                   Event Medal
# 53519   Beijing  Tennis  Tennis Women's Singles  Gold
# 67290   Beijing  Tennis    Tennis Men's Doubles  Gold
# 167223  Beijing  Tennis    Tennis Men's Singles  Gold
# 257672  Beijing  Tennis    Tennis Men's Doubles  Gold
# 261109  Beijing  Tennis  Tennis Women's Doubles  Gold
# 261163  Beijing  Tennis  Tennis Women's Doubles  Gold

# %%
# швейцарцы
data[(data['Year'] == 2008) & (data['Sport'] == 'Tennis') & (data['Medal'] == 'Gold') & (data['Team'] == 'Switzerland')]

#выходит хоть они и взяли 1 комплект (федерер в паре с варвинкой), но суммарно 2 медали
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City   Sport                 Event  \
# 67290   SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
# 257672  SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
#
#        Medal
# 67290   Gold
# 257672  Gold

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
#почистим NaN
i1 = data[(data['Year'] == 2016) & (data['Team'] == 'Spain') & (data['Medal'].notna())]
print(i1['Medal'].count())
i1
# Out:
# 43
#             ID                                        Name Sex   Age  Height  \
# 1029       576             Alejandro "lex" Abrines Redondo   M  23.0   198.0
# 2280      1262                      Sandra Aguilar Navarro   F  23.0   167.0
# 17793     9464                             Ruth Beita Vila   F  37.0   191.0
# 18414     9750                       Mireia Belmonte Garca   F  25.0   170.0
# 18416     9750                       Mireia Belmonte Garca   F  25.0   170.0
# 33775    17402                 Jos Manuel Caldern Borrallo   M  34.0   191.0
# 34027    17525                              Eva Calvo Gmez   F  25.0   176.0
# 41074    21174                Maialen Chourraut Yurramendi   F  33.0   161.0
# 42529    21935                         Vctor Claver Arocas   M  27.0   206.0
# 43631    22498                        Carlos Coloma Nicols   M  34.0   171.0
# 45926    23703                        Sal Craviotto Rivero   M  31.0   192.0
# 45927    23703                        Sal Craviotto Rivero   M  31.0   192.0
spain  ESP  2016 Summer  2016  Summer  Rio de Janeiro
#
#                       Sport                                          Event  \
# 1029             Basketball                    Basketball Men's Basketball
# 2280    Rhythmic Gymnastics              Rhythmic Gymnastics Women's Group
# 17793             Athletics                    Athletics Women's High Jump
# 18414              Swimming          Swimming Women's 200 metres Butterfly
# 18416              Swimming  Swimming Women's 400 metres Individual Medley
# 33775            Basketball                    Basketball Men's Basketball
# 34027             Taekwondo                Taekwondo Women's Featherweight
# 41074              Canoeing         Canoeing Women's Kayak Singles, Slalom
# 42529            Basketball                    Basketball Men's Basketball
# 43631               Cycling      Cycling Men's Mountainbike, Cross-Country
# 45926              Canoeing       Canoeing Men's Kayak Singles, 200 metres
# 45927              Canoeing       Canoeing Men's Kayak Doubles, 200 metres
# 46559            Basketball                  Basketball Women's Basketball
# 57148            Basketball                  Basketball Women's Basketball
# 68274            Basketball                    Basketball Men's Basketball
# 76754            Basketball                    Basketball Men's Basketball
# 77104   Rhythmic Gymnastics              Rhythmic Gymnastics Women's Group
# 79253            Basketball                  Basketball Women's Basketball
# 81822             Taekwondo                  Taekwondo Men's Featherweight
# 95006            Basketball                    Basketball Men's Basketball
# 141213           Basketball                    Basketball Men's Basketball
# 142213  Rhythmic Gymnastics              Rhythmic Gymnastics Women's Group
# 149622            Badminton                      Badminton Women's Singles
# 160013           Basketball                    Basketball Men's Basketball
# 161323  Rhythmic Gymnastics              Rhythmic Gymnastics Women's Group
# 168680           Basketball                    Basketball Men's Basketball
# 168986           Basketball                  Basketball Women's Basketball
# 170723           Basketball                  Basketball Women's Basketball
# 178179            Athletics             Athletics Men's 110 metres Hurdles
# 180519           Basketball                  Basketball Women's Basketball
# 182817           Basketball                  Basketball Women's Basketball
# 195008  Rhythmic Gymnastics              Rhythmic Gymnastics Women's Group
# 195047           Basketball                  Basketball Women's Basketball
# 199548           Basketball                    Basketball Men's Basketball
# 202703           Basketball                  Basketball Women's Basketball
# 202775           Basketball                    Basketball Men's Basketball
# 203801           Basketball                  Basketball Women's Basketball
# 205588           Basketball                    Basketball Men's Basketball
# 241970             Canoeing       Canoeing Men's Kayak Doubles, 200 metres
# 242043           Basketball                  Basketball Women's Basketball
# 247578        Weightlifting              Weightlifting Women's Heavyweight
# 256343             Canoeing     Canoeing Men's Kayak Singles, 1,000 metres
# 263736           Basketball                  Basketball Women's Basketball
#
#          Medal
# 1029    Bronze
# 2280    Silver
# 17793     Gold
# 18414     Gold
# 18416   Bronze
# 33775   Bronze
# 34027   Silver
# 41074     Gold
# 42529   Bronze
# 43631   Bronze
# 45926   Bronze
# 45927     Gold
# 46559   Silver
# 57148   Silver
# 68274   Bronze
# 76754   Bronze
# 77104   Silver
# 79253   Silver
# 81822   Bronze
# 95006   Bronze
# 141213  Bronze
# 142213  Silver
# 149622    Gold
# 160013  Bronze
# 161323  Silver
# 168680  Bronze
# 168986  Silver
# 170723  Silver
# 178179  Silver
# 180519  Silver
# 182817  Silver
# 195008  Silver
# 195047  Silver
# 199548  Bronze
# 202703  Silver
# 202775  Bronze
# 203801  Silver
# 205588  Bronze
# 241970    Gold
# 242043  Silver
# 247578  Bronze
# 256343    Gold
# 263736  Silver

# %%
i2 = data[(data['Year'] == 2016) & (data['Team'] == 'Italy') & (data['Medal'].notna())]
print(i2['Medal'].count())
i2
# Out:
# 70
#             ID                         Name Sex   Age  Height  Weight   Team  \
# 158         62            Giovanni Abagnale   M  21.0   198.0    90.0  Italy
# 2616      1466               Matteo Aicardi   M  30.0   192.0   102.0  Italy
# 2635      1478               Rosaria Aiello   F  27.0   172.0    74.0  Italy
# 8300      4575                 Oleg Antonov   M  28.0   198.0    88.0  Italy
# 12186     6624                 Diana Bacosi   F  33.0   175.0    85.0  Italy
# 15685     8452                 Fabio Basile   M  21.0   160.0    66.0  Italy
# 21375    11278             Roberta Bianconi   F  27.0   176.0    76.0  Italy
# 22122    11653           Emanuele Birarelli   M  35.0   202.0    95.0  Italy
# 23980    12593     Michal Alexandre Bodegas   M  29.0   192.0   102.0  Italy
# 30644    15788                Rachele Bruni   F  25.0   170.0    59.0  Italy
# 32866    16900                  Simone Buti   M  32.0   206.0   100.0  Italy
# 33495    17272    Tania Cagnotto (-Parolin)   F  31.0   160.0    54.0  Italy
# 33496    17272    Tania Cagnotto (-Parolin)   F  31.0   160.0    54.0  Italy
# 33578    17318               Chiara Cainero   F  38.0   171.0    81.0  Italy
# 34560    17815             Niccol Campriani   M  28.0   177.0    80.0  Italy
# 34561    17815             Niccol Campriani   M  28.0   177.0    80.0  Italy
# 36723    18870              Matteo Castaldo   M  30.0   188.0    86.0  Italy
# 38218    19643        Frank Chamizo Marquez   M  24.0   172.0    65.0  Italy
# 43263    22299               Massimo Colaci   M  31.0   180.0    75.0  Italy
# 45329    23387             Aleksandra Cotti   F  27.0   167.0    65.0  Italy
# 48510    25003             Francesca Dallap   F  30.0   163.0    57.0  Italy
# 52825    27123              Marco Del Lungo   M  26.0   190.0    97.0  Italy
# 54370    27897               Gabriele Detti   M  21.0   184.0    79.0  Italy
# 54371    27897               Gabriele Detti   M  21.0   184.0    79.0  Italy
# 54773    28068            Marco Di Costanzo   M  24.0   184.0    87.0  Italy
# 54788    28072           Elisa Di Francisca   F  33.0   177.0    65.0  Italy
# 54789    28073          Francesco Di Fulvio   M  22.0   190.0    88.0  Italy
# 54811    28086               Tania Di Mario   F  37.0   168.0    62.0  Italy
# 63439    32516         Giulia Enrica Emmolo   F  24.0   171.0    67.0  Italy
# 68887    35134            Rossella Fiamingo   F  25.0   167.0    50.0  Italy
# ...        ...                          ...  ..   ...     ...     ...    ...
# 80034    40617             Odette Giuffrida   F  21.0   160.0    52.0  Italy
# 82406    41869               Giulia Gorlero   F  25.0   180.0    73.0  Italy
# 103138   52180              Marco Innocenti   M  37.0   170.0    97.0  Italy
# 111019   56171  Osmany Juantorena Portuondo   M  30.0   200.0    85.0  Italy
# 132278   66575                Filippo Lanza   M  25.0   198.0    98.0  Italy
# 141484   70992                  Matteo Lodo   M  21.0   196.0    90.0  Italy
# 142002   71235         Elisa Longo Borghini   F  24.0   170.0    59.0  Italy
# 162497   81588            Domenico Montrone   M  30.0   189.0    97.0  Italy
# 172822   86838              Alessandro Nora   M  29.0   191.0    85.0  Italy
# 180872   90906         Gregorio Paltrinieri   M  21.0   191.0    72.0  Italy
# 184812   92881            Giovanni Pellielo   M  46.0   173.0    93.0  Italy
# 188200   94549                 Matteo Piano   M  25.0   208.0   102.0  Italy
# 192916                        Water Polo Men's Water Polo  Bronze
# 194961                      Water Polo Women's Water Polo  Silver
# 195506                      Water Polo Women's Water Polo  Silver
# 204607                               Shooting Men's Skeet    Gold
# 204684                        Volleyball Men's Volleyball  Silver
# 210229                           Fencing Men's epee, Team  Silver
# 225657                        Volleyball Men's Volleyball  Silver
# 234680                      Water Polo Women's Water Polo  Silver
# 237254                      Water Polo Women's Water Polo  Silver
# 237533                        Water Polo Men's Water Polo  Bronze
# 251230                        Water Polo Men's Water Polo  Bronze
# 252102                        Volleyball Men's Volleyball  Silver
# 252281                         Rowing Men's Coxless Fours  Bronze
# 253492                               Cycling Men's Omnium    Gold
# 268133                        Volleyball Men's Volleyball  Silver
#
# [70 rows x 15 columns]

# %%
print('Spain won {} medals, Italy won {} medals, statement is {}'.format(i1['Medal'].count(), i2['Medal'].count(), i1['Medal'].count()<i2['Medal'].count()))
# Out:
# Spain won 43 medals, Italy won 70 medals, statement is True

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
# hist
data[data['Year'] == 2008]['Age'].hist()
#i1 = [45-55]
i1 = data[(data['Year'] == 2008) & (data['Age'] >= 45) & (data['Age'] <= 55)]['ID'].unique().size
#i2 = [35-45)
i2 = data[(data['Year'] == 2008) & (data['Age'] >= 35) & (data['Age'] < 45)]['ID'].unique().size
#i3 = [25-35)
i3 = data[(data['Year'] == 2008) & (data['Age'] >= 25) & (data['Age'] < 35)]['ID'].unique().size
#i4 = [15-25)
i4 = data[(data['Year'] == 2008) & (data['Age'] >= 15) & (data['Age'] < 25)]['ID'].unique().size

print('[45-55]: {}; [35-45):{}; [25-35): {}; [15-25): {}'.format(i1, i2, i3, i4))
#Then fewest - [45-55]; most participants - [25-35). A.
# Out:
# [45-55]: 78; [35-45):630; [25-35): 5382; [15-25): 4786

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
print(data[(data['Season'] == 'Summer') & (data['City'] == 'Atlanta')]['Year'].unique())
print(data[(data['Season'] == 'Winter') & (data['City'] == 'Squaw Valley')]['Year'].unique())
# Yes, Yes
# Out:
# [1996]
# [1960]

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15
# - 27

# %%
sp1 = data[data['Year'] == 1986]['Sport'].unique()
sp2 = data[data['Year'] == 2002]['Sport'].unique()
print('In 1986 we had {} sports against {} in 2002'.format(sp1.size,sp2.size))
# Out:
# In 1986 we had 0 sports against 15 in 2002

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
